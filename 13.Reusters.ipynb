# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# 로이터 뉴스 데이터 셋 불러오기
from tensorflow.keras.datasets import reuters
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM,Embedding
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.utils import to_categorical

# %%
(X_train, Y_train), (X_test, Y_test) =\
                reuters.load_data(num_words=1000, test_split=0.2)
# Out:
# C:\Users\bit\anaconda3\envs\deeprun\lib\site-packages\tensorflow\python\keras\datasets\reuters.py:148: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# C:\Users\bit\anaconda3\envs\deeprun\lib\site-packages\tensorflow\python\keras\datasets\reuters.py:149: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])

# %%
category = np.max(Y_train) + 1
print(category, '카테고리')
print(len(X_train), '학습용 뉴스 기사')
print(len(X_test), '테스트용 뉴스 기사')
print(X_train[0])
# Out:
# 46 카테고리
# 8982 학습용 뉴스 기사
# 2246 테스트용 뉴스 기사
# [1, 2, 2, 8, 43, 10, 447, 5, 25, 207, 270, 5, 2, 111, 16, 369, 186, 90, 67, 7, 89, 5, 19, 102, 6, 19, 124, 15, 90, 67, 84, 22, 482, 26, 7, 48, 4, 49, 8, 864, 39, 209, 154, 6, 151, 6, 83, 11, 15, 22, 155, 11, 15, 7, 48, 9, 2, 2, 504, 6, 258, 6, 272, 11, 15, 22, 134, 44, 11, 15, 16, 8, 197, 2, 90, 67, 52, 29, 209, 30, 32, 132, 6, 109, 15, 17, 12]

# %%
x_train = sequence.pad_sequences(X_train, maxlen=100)
x_test = sequence.pad_sequences(X_test, maxlen=100)
y_train = to_categorical(Y_train)
y_test = to_categorical(Y_test)

# %%
print(Y_train[0])
# Out:
# 3

# %%
model = Sequential()
model.add(Embedding(1000,100))
model.add(LSTM(100, activation ='tanh'))
model.add(Dense(46, activation ='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(x_train, y_train, batch_size=100, epochs=20, validation_data=(x_test, y_test))

print("\n Test Accuracy: %.4f" % (model.evaluate(x_test, y_test)[1]))
# Out:
# Epoch 1/20
# 90/90 [==============================] - 10s 114ms/step - loss: 2.5551 - accuracy: 0.3643 - val_loss: 2.1402 - val_accuracy: 0.4608
# Epoch 2/20
# 90/90 [==============================] - 10s 109ms/step - loss: 1.9841 - accuracy: 0.4981 - val_loss: 1.8614 - val_accuracy: 0.5236
# Epoch 3/20
# 90/90 [==============================] - 9s 104ms/step - loss: 1.8348 - accuracy: 0.5016 - val_loss: 1.7666 - val_accuracy: 0.5516
# Epoch 4/20
# 90/90 [==============================] - 9s 104ms/step - loss: 1.7407 - accuracy: 0.5510 - val_loss: 1.7585 - val_accuracy: 0.5499
# Epoch 5/20
# 90/90 [==============================] - 9s 97ms/step - loss: 1.6621 - accuracy: 0.5694 - val_loss: 1.6672 - val_accuracy: 0.5850
# Epoch 6/20
# 90/90 [==============================] - 9s 99ms/step - loss: 1.5883 - accuracy: 0.5890 - val_loss: 1.6236 - val_accuracy: 0.5855
# Epoch 7/20
# 90/90 [==============================] - 8s 94ms/step - loss: 1.5176 - accuracy: 0.6057 - val_loss: 1.5753 - val_accuracy: 0.6002
# Epoch 8/20
# 90/90 [==============================] - 9s 98ms/step - loss: 1.4177 - accuracy: 0.6353 - val_loss: 1.5303 - val_accuracy: 0.6118
# Epoch 9/20
# 90/90 [==============================] - 9s 95ms/step - loss: 1.3682 - accuracy: 0.6441 - val_loss: 1.4656 - val_accuracy: 0.6207
# Epoch 10/20
# 90/90 [==============================] - 9s 98ms/step - loss: 1.2716 - accuracy: 0.6776 - val_loss: 1.4023 - val_accuracy: 0.6420
# Epoch 11/20
# 90/90 [==============================] - 9s 102ms/step - loss: 1.1893 - accuracy: 0.6966 - val_loss: 1.3252 - val_accuracy: 0.6594
# Epoch 12/20
# 90/90 [==============================] - 9s 101ms/step - loss: 1.1314 - accuracy: 0.7101 - val_loss: 1.2922 - val_accuracy: 0.6732
# Epoch 13/20
# 90/90 [==============================] - 9s 103ms/step - loss: 1.0658 - accuracy: 0.7300 - val_loss: 1.2711 - val_accuracy: 0.6714
# Epoch 14/20
# 90/90 [==============================] - 9s 98ms/step - loss: 1.0300 - accuracy: 0.7390 - val_loss: 1.2748 - val_accuracy: 0.6790
# Epoch 15/20
# 90/90 [==============================] - 9s 97ms/step - loss: 0.9816 - accuracy: 0.7505 - val_loss: 1.2837 - val_accuracy: 0.6776
# Epoch 16/20
# 90/90 [==============================] - 9s 98ms/step - loss: 0.9532 - accuracy: 0.7571 - val_loss: 1.2360 - val_accuracy: 0.6959
# Epoch 17/20
# 90/90 [==============================] - 9s 99ms/step - loss: 0.9013 - accuracy: 0.7714 - val_loss: 1.2335 - val_accuracy: 0.6950
# Epoch 18/20
# 90/90 [==============================] - 9s 98ms/step - loss: 0.8549 - accuracy: 0.7828 - val_loss: 1.2018 - val_accuracy: 0.7106
# Epoch 19/20
# 90/90 [==============================] - 9s 97ms/step - loss: 0.8113 - accuracy: 0.7959 - val_loss: 1.2117 - val_accuracy: 0.7021
# Epoch 20/20
# 90/90 [==============================] - 9s 104ms/step - loss: 0.7854 - accuracy: 0.8033 - val_loss: 1.2278 - val_accuracy: 0.7004
# 71/71 [==============================] - 1s 19ms/step - loss: 1.2278 - accuracy: 0.7004
#
#  Test Accuracy: 0.7004

# %%
y_vloss = history.history['val_loss']
y_loss = history.history['loss']

# %%
x_len = np.arange(len(y_loss))
plt.plot(x_len, y_vloss, marker='.', c="red", label='Testset_loss')
plt.plot(x_len, y_loss, marker='.', c="blue", label='Trainset_loss')

plt.legend(loc='upper right')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()
